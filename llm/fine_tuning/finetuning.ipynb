# %%
import tensorflow as tf
import torch

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")

inputs = tokenizer("Hello, my name is", return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=20)
print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# c:\ProgramData\anaconda3\envs\finetune\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\mamma\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
import torch
import torch.nn as nn

logits = torch.tensor([[1.5, 0.3, 2.1]])   # raw model output
labels = torch.tensor([2])                # true class index

loss_fn = nn.CrossEntropyLoss()
loss = loss_fn(logits, labels)
print(loss.item())
# Out:
# 0.5388943552970886

# %%
import anyio
print(anyio.__file__)
print(anyio.__version__)
# Out:
# c:\ProgramData\anaconda3\envs\finetune\Lib\site-packages\anyio\__init__.py
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import anyio
#       2 print(anyio.__file__)
# ----> 3 print(anyio.__version__)
#
# AttributeError: module 'anyio' has no attribute '__version__'

# %%
import dspy

# %%
from typing import List
def twoSum( nums: List[int], target: int) -> List[int]:
    for i in range(len(nums)//2+1):
        print(i)
        for j in range(i+1, len(nums)):
            if nums[i]+nums[j]==target:
                return[i,j]
twoSum([3,2,4],6)
# Out:
# 0
# 1
# [1, 2]

# %%
aa = [1,1,3,4,5]
bb = [6,7,8,9,10]
cc = [11,12,13,14,15]
dd = [16,17,18,19,20]
ee = [21,22,23,24,25]
ff = [26,27,28,29,30]
gg = [31,32,33,34,35]
hh = [36,37,38,39,40]
ii = [41,42,43,44,45]
jj = [46,47,48,49,50]
kk = [51,52,53,54,55]

# %%
aa = [1,1,3,1,5]
j=0
while j<len(aa)>0:
    print(j)
    if aa[j]==1:
        aa.pop(j)
    else:
        j+=1
        
    print(aa)
# Out:
# 0
# [1, 3, 1, 5]
# 0
# [3, 1, 5]
# 0
# [3, 1, 5]
# 1
# [3, 5]
# 1
# [3, 5]

# %%
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        anan = []
        i = 0
        while len(strs)>0:
            print(strs[i], strs)
            items = []
            items.append(strs[i])
            item = strs[i]
            strs.pop(i)
            j = i
            while j<len(strs):
                print(sorted(item),sorted(strs[j]))
                if "".join(sorted(item)) == "".join(sorted(strs[j])):
                    print(item,strs[j], "".join(sorted(item)) == "".join(sorted(strs[j])))
                    items.append(strs[j])
                    strs.pop(j)
                else:
                    j+=1
            anan.append(items)

        return anan
ss = Solution()
ss.groupAnagrams(["eat","tea","tan","ate","nat","bat"])
# Out:
# eat ['eat', 'tea', 'tan', 'ate', 'nat', 'bat']
# ['a', 'e', 't'] ['a', 'e', 't']
# eat tea True
# ['a', 'e', 't'] ['a', 'n', 't']
# ['a', 'e', 't'] ['a', 'e', 't']
# eat ate True
# ['a', 'e', 't'] ['a', 'n', 't']
# ['a', 'e', 't'] ['a', 'b', 't']
# tan ['tan', 'nat', 'bat']
# ['a', 'n', 't'] ['a', 'n', 't']
# tan nat True
# ['a', 'n', 't'] ['a', 'b', 't']
# bat ['bat']
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
import pandas as pd

# %%
values = [8, 10.7, 17.1, 11.2, 13.5, 9.9, 14.9, 9.4, 9.4, 3.1, 12.7]
df = pd.Series(values).to_frame("rad")
df["p"] = df["rad"].shift(1)
df["n"] = df["rad"].shift(-1)
df["peak"] = (df["rad"] >= - df["p"]+5) & (df["rad"] >= df["n"]+5)
df["but"] = (df["rad"] <= - df["p"]-5) & (df["rad"] <= df["n"]-5)
df["peak"].sum() + df["but"].sum()
# Out:
# 3

# %%
df
# Out:
#      rad     p     n   peak    but
# 0    8.0   NaN  10.7  False  False
# 1   10.7   8.0  17.1  False  False
# 2   17.1  10.7  11.2   True  False
# 3   11.2  17.1  13.5  False  False
# 4   13.5  11.2   9.9  False  False
# 5    9.9  13.5  14.9  False  False
# 6   14.9   9.9   9.4   True  False
# 7    9.4  14.9   9.4  False  False
# 8    9.4   9.4   3.1   True  False
# 9    3.1   9.4  12.7  False  False
# 10  12.7   3.1   NaN  False  False

# %%
from json import dumps, loads 
import sys 
from typing import List 
import pandas as pd 
def (values :  List [float]) int : 
    df = pd. Series (values) . to_frame( "rad" ) 
     
    df["p"] = df["rad"].shift(l) 
    df["n"] = df["rad"].shift(-l) 
    df["peak"] = (df["rad"] >= - df["p"]+5) & (df["rad"] >= df["n"]+5)
    df["but"] = (df["rad"] <= - df["p"]-5) & (df["rad"] <= df["n"]-5)
return: 62
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 "".join(sorted(item))
#
# NameError: name 'item' is not defined

# %%
"abc"== "".join(sorted("cba"))
# Out:
# True

# %%
"".join(sorted("cba"))
# Out:
# 'abc'
