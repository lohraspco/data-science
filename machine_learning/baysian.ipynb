# %% [markdown]
# Bayesian thinking is about updating your beliefs as new evidence comes in—you start with what you think is likely (your prior belief) and adjust it based on the data you observe. It’s like guessing the weather: you might think it’s usually sunny in August, but if you see dark clouds forming, you   your prediction to expect rain.

# %% [markdown]
# ![image.png](attachment:image.png)
